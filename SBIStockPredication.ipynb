# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt


df=pd.read_csv('/content/sbiE.csv')
xs=df['OPEN']
ys=df['Date']
#plt.plot(xs,ys)
#plt.show()

df.describe()

df['Date']=pd.to_datetime(df['Date'])
#df.info()
model=LinearRegression()

#df[['OPEN']]
#df['OPEN']
#df.OPEN

model.fit(df[['OPEN']],df.Date)

model.score(df[['OPEN']],df.Date)




model.predict([[df.Date[0].value]])

plt.scatter(df.OPEN,df.Date)
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
model2=LinearRegression()
model2.fit(df[['OPEN']],df.Date)
model2.score(df[['OPEN']],df.Date)

df.describe()
df.info()
df

inData=df[['OPEN']]
inData

newDataFram=df

newDataFram['predictDate']=model.predict(inData)
newDataFram['predictDate']=pd.to_datetime(newDataFram['predictDate'])
newDataFram
newDataFram.to_csv('SBIStockPredictDate.csv')
plt.plot(newDataFram.OPEN,pd.to_datetime(model.predict(newDataFram[['OPEN']])),color='blue')
plt.show()


pre=model.predict([[774.8]])
pd.to_datetime(pre)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          249 non-null    datetime64[ns]
#  1   series        249 non-null    object
#  2   OPEN          249 non-null    float64
#  3   HIGH          249 non-null    float64
#  4   LOW           249 non-null    float64
#  5   PREV. CLOSE   249 non-null    float64
#  6   ltp           249 non-null    float64
#  7   close         249 non-null    float64
#  8   vwap          249 non-null    float64
#  9   52W H         249 non-null    float64
#  10  52W L         249 non-null    float64
#  11  VOLUME        249 non-null    object
#  12  VALUE         249 non-null    object
#  13  No of trades  249 non-null    object
#  14  predictDate   249 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), float64(9), object(4)
# memory usage: 29.3+ KB
# ...

# %%
pre=model.predict([[1000]])
pd.to_datetime(pre)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# DatetimeIndex(['2025-01-01 11:37:45.358706944'], dtype='datetime64[ns]', freq=None)
